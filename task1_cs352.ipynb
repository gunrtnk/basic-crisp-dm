# %% [markdown]
# <a href="https://colab.research.google.com/github/gunrtnk/CS352-6109680089/blob/main/task1_cs352.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
soda_df=pd.read_csv('/content/drive/MyDrive/cs352/soda.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#from google.colab import files
#uploaded = files.upload()

# %%
#from google.colab import files
#uploaded = files.upload()

# %%
from google.colab import drive
drive.mount('/content/drive')
inv_df=pd.read_csv('/content/drive/MyDrive/cs352/invoice.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#soda_df= pd.read_csv("soda.csv")
soda_df
# Out:
#       Item_id            Item_Description         Category  Pack  \
# 0         101     Kanna's Grapefruit Soda  Grapefruit Soda     6
# 1         102      Alphonse's Fruit Punch      Fruit Punch     6
# 2         103    Yummy Surstromming Juice              NaN     1
# 3         107   Tamaki's Watermelon Cream       Cream Soda     6
# 4         108     Kaori's Grapefruit Soda  Grapefruit Soda     6
# ...       ...                         ...              ...   ...
# 4161   994644        Saitama's Cream Soda       Cream Soda     6
# 4162   994786  Kenji's Vanilla Cream Soda       Cream Soda     6
# 4163   994972  Tanya's Vanilla Cream Soda       Cream Soda     6
# 4164   995606         Sakura's Cream Soda       Cream Soda    12
# 4165   996026        Tetsuya's Cream Soda       Cream Soda     6
#
#       Bottle_Volume_ml  Bottle_Cost  Bottle_Retail_Price
# 0                750.0         4.32                 6.48
# 1                800.0         3.33                 5.00
# ...

# %%
print(soda_df.head())
soda_df.info
# Out:
#    Item_id           Item_Description         Category  Pack  \
# 0      101    Kanna's Grapefruit Soda  Grapefruit Soda     6
# 1      102     Alphonse's Fruit Punch      Fruit Punch     6
# 2      103   Yummy Surstromming Juice              NaN     1
# 3      107  Tamaki's Watermelon Cream       Cream Soda     6
# 4      108    Kaori's Grapefruit Soda  Grapefruit Soda     6
#
#    Bottle_Volume_ml  Bottle_Cost  Bottle_Retail_Price
# 0             750.0         4.32                 6.48
# 1             800.0         3.33                 5.00
# 2             750.0        10.30                20.10
# 3             750.0         4.44                 6.66
# 4             750.0         3.12                 4.68
# <bound method DataFrame.info of       Item_id            Item_Description         Category  Pack  \
# 0         101     Kanna's Grapefruit Soda  Grapefruit Soda     6
# 1         102      Alphonse's Fruit Punch      Fruit Punch     6
# ...

# %%
soda_df['Pack_Total_Cost']= soda_df['Pack']*soda_df['Bottle_Cost']
soda_df
# Out:
#       Item_id            Item_Description         Category  Pack  \
# 0         101     Kanna's Grapefruit Soda  Grapefruit Soda     6
# 1         102      Alphonse's Fruit Punch      Fruit Punch     6
# 2         103    Yummy Surstromming Juice              NaN     1
# 3         107   Tamaki's Watermelon Cream       Cream Soda     6
# 4         108     Kaori's Grapefruit Soda  Grapefruit Soda     6
# ...       ...                         ...              ...   ...
# 4161   994644        Saitama's Cream Soda       Cream Soda     6
# 4162   994786  Kenji's Vanilla Cream Soda       Cream Soda     6
# 4163   994972  Tanya's Vanilla Cream Soda       Cream Soda     6
# 4164   995606         Sakura's Cream Soda       Cream Soda    12
# 4165   996026        Tetsuya's Cream Soda       Cream Soda     6
#
#       Bottle_Volume_ml  Bottle_Cost  Bottle_Retail_Price  Pack_Total_Cost
# 0                750.0         4.32                 6.48            25.92
# ...

# %%
grouped_soda=soda_df.groupby('Category').agg({"Pack_Total_Cost":"count"})
grouped_soda
# Out:
#                  Pack_Total_Cost
# Category
# Blueberry Soda                40
# Cherry Soda                 1019
# Cola                         251
# Cream Soda                   899
# Energy Drink                 339
# Fruit Punch                  319
# Ginger Ale                   314
# Grapefruit Soda               60
# Lime Soda                    190
# Orange Soda                  186
# Raspberry Soda               127
# Root Beer                    418

# %%
grouped_soda.sort_values(["Pack_Total_Cost"], ascending = [False])
# Out:
#                  Pack_Total_Cost
# Category
# Cherry Soda                 1019
# Cream Soda                   899
# Root Beer                    418
# Energy Drink                 339
# Fruit Punch                  319
# Ginger Ale                   314
# Cola                         251
# Lime Soda                    190
# Orange Soda                  186
# Raspberry Soda               127
# Grapefruit Soda               60
# Blueberry Soda                40

# %%
grouped_soda.plot.pie(subplots=True ,figsize=(50, 15))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7416015750>],
#       dtype=object)

# %%
soda_df['Pack_Price']= soda_df['Pack']*soda_df['Bottle_Retail_Price']
soda_df
# Out:
#       Item_id            Item_Description         Category  Pack  \
# 0         101     Kanna's Grapefruit Soda  Grapefruit Soda     6
# 1         102      Alphonse's Fruit Punch      Fruit Punch     6
# 2         103    Yummy Surstromming Juice              NaN     1
# 3         107   Tamaki's Watermelon Cream       Cream Soda     6
# 4         108     Kaori's Grapefruit Soda  Grapefruit Soda     6
# ...       ...                         ...              ...   ...
# 4161   994644        Saitama's Cream Soda       Cream Soda     6
# 4162   994786  Kenji's Vanilla Cream Soda       Cream Soda     6
# 4163   994972  Tanya's Vanilla Cream Soda       Cream Soda     6
# 4164   995606         Sakura's Cream Soda       Cream Soda    12
# 4165   996026        Tetsuya's Cream Soda       Cream Soda     6
#
#       Bottle_Volume_ml  Bottle_Cost  Bottle_Retail_Price  Pack_Total_Cost  \
# 0                750.0         4.32                 6.48            25.92
# ...

# %%
soda_df['profit_margin']= (soda_df['Bottle_Retail_Price']-soda_df['Bottle_Cost'])/soda_df['Bottle_Cost']
soda_df
# Out:
#       Item_id            Item_Description         Category  Pack  \
# 0         101     Kanna's Grapefruit Soda  Grapefruit Soda     6
# 1         102      Alphonse's Fruit Punch      Fruit Punch     6
# 2         103    Yummy Surstromming Juice              NaN     1
# 3         107   Tamaki's Watermelon Cream       Cream Soda     6
# 4         108     Kaori's Grapefruit Soda  Grapefruit Soda     6
# ...       ...                         ...              ...   ...
# 4161   994644        Saitama's Cream Soda       Cream Soda     6
# 4162   994786  Kenji's Vanilla Cream Soda       Cream Soda     6
# 4163   994972  Tanya's Vanilla Cream Soda       Cream Soda     6
# 4164   995606         Sakura's Cream Soda       Cream Soda    12
# 4165   996026        Tetsuya's Cream Soda       Cream Soda     6
#
#       Bottle_Volume_ml  Bottle_Cost  Bottle_Retail_Price  Pack_Total_Cost  \
# 0                750.0         4.32                 6.48            25.92
# ...

# %%
#inv_df= pd.read_csv("invoice.csv")
inv_df
# Out:
#              Invoice_id        Date  Item_id  Vendor_id          Vendor_Name  \
# 0       INV-00013400001  2016-08-29    35918        297        Katou Company
# 1       INV-00013400002  2016-08-29    23828        297        Katou Company
# 2       INV-00013400003  2016-08-29    36908        300    Katsuragi Company
# 3       INV-00013400004  2016-08-29    34359         35          Archer Inc.
# 4       INV-00013400005  2016-08-29    36903        300    Katsuragi Company
# ...                 ...         ...      ...        ...                  ...
# 930503     S34122500013  2016-08-25    68031        260      Inuyasha Brands
# 930504     S34122500014  2016-08-25    75212        322        Koizumi Group
# 930505     S34122500015  2016-08-25    75224        322        Koizumi Group
# 930506     S34122500016  2016-08-25    36901        300    Katsuragi Company
# 930507     S34122500017  2016-08-25    86692         85  Ayuzawa Corporation
#
# ...

# %%
grouped_inv_county=inv_df.groupby('City_Name').agg({"Bottles_Sold":"count"})
grouped_inv_county
# Out:
#             Bottles_Sold
# City_Name
# DAVENPORT         569608
# SIOUX CITY        360900

# %%
grouped_inv_v=inv_df.groupby('Store_Name').agg({"Bottles_Sold":"count"})
grouped_inv_v
# Out:
#                                Bottles_Sold
# Store_Name
# ATC Durg                               8358
# Artisan Craft Soda                       14
# Bacon Creek Country Store               197
# Brady Mart / Davenport                  440
# Brady Mart Food & Durg                 9529
# ...                                     ...
# Walgreens #06186 / Davenport           1153
# Walgreens #11709 / Davenport           1836
# Walgreens #15647 / Sioux City          1106
# Washington Street Mini Mart           17145
# West Side Grocery                      1778
#
# [98 rows x 1 columns]

# %%
grouped_inv_county.plot.pie(subplots=True ,figsize=(30, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f74161692d0>],
#       dtype=object)

# %%
soda_df['Bottle_Cost'].describe()

# %%
inv_soda =inv_df.merge(soda_df, how='outer')
inv_soda

# %%
inv_soda =inv_df.merge(soda_df, how='inner' )
inv_soda

# %%
inv_soda_new =inv_df.merge(soda_df, how='right' , left_on="Item_id", right_on="Item_id" )
inv_soda

# %%
inv_soda_new[inv_soda_new['Invoice_id'].isnull()]['Item_Description']

# %%
grouped_df=inv_soda_new.groupby('Item_Description').agg({"Invoice_id":"count"}).max()
grouped_df

# %%
grouped_df=inv_soda_new.groupby('Item_Description').agg({"Invoice_id":"count"})
type(grouped_df)
sodaneww=inv_soda_new['Invoice_id']
ans=(grouped_df['Invoice_id']).idxmax()
ans
#inv_soda_new['Item_Description'].idxmax()

# %%
grouped_df_min=inv_soda_new.groupby('Item_Description').agg({"Vendor_id":"count"})


ans_min=(grouped_df_min['Vendor_id']).idxmin()
ans_min

ans2=grouped_df_min.min()
ans2

ans_min

# %%
# Q8: Which soda has the largest number of invoiced
grouped_df.max()
grouped_df.info()

# %%
# Q9 : Find Average Bottle_Cost And Bottle_Retail_Price
soda_df['Bottle_Cost_Avg']= soda_df['Bottle_Cost'].mean()
soda_df['Bottle_Retail_Avg']= soda_df['Bottle_Retail_Price'].mean()
soda_df

# %%
grouped_dfsoda=soda_df.groupby('Category').agg({"Bottle_Cost":"mean"})
grouped_dfsoda

# %%
# Q10 : pivot
pd.pivot_table(inv_soda_new, values="Bottles_Sold",\
               index = ["Vendor_Name"],\
               columns=["Category"],aggfunc="sum")
